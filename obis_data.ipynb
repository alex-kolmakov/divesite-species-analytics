# %%
import pandas as pd
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master("local[*]") \
    .appName('test') \
    .config("spark.executor.memory", "10g") \
    .config("spark.driver.memory", "10g") \
    .config("spark.memory.offHeap.enabled", "true") \
    .config("spark.memory.offHeap.size","16g") \
    .getOrCreate()

pd.set_option('display.max_columns', 500)

# %%
#!wget "https://obis-datasets.ams3.digitaloceanspaces.com/exports/obis_20231025.parquet"
#!wget "https://hosted-datasets.gbif.org/datasets/gisd_2011-11-20.zip"
#!wget "https://hosted-datasets.gbif.org/datasets/iucn/iucn-2022-1.zip"


df = spark.read \
    .parquet('/Users/helloworld/Downloads/obis_20231025.parquet')

# %%
from dwca.read import DwCAReader

with DwCAReader('/Users/helloworld/Downloads/gisd_2011-11-20.zip') as dwca:
   print("Core data file is: {}".format(dwca.descriptor.core.file_location)) # => 'taxon.txt'

   invasive_df = dwca.pd_read(dwca_red.descriptor.core.file_location, parse_dates=True)


with DwCAReader('/Users/helloworld/Downloads/iucn-2022-1.zip') as dwca_red:
   print("Core data file is: {}".format(dwca_red.descriptor.core.file_location)) # => 'taxon.txt'

   redlist_df = dwca_red.pd_read(dwca_red.descriptor.core.file_location, parse_dates=True)

redlist_df = redlist_df.dropna(subset=["scientificNameAuthorship"])
redlist_df['scientificName'] = redlist_df.apply(lambda row: row['scientificName'].replace(row['scientificNameAuthorship'], '').strip(), axis=1)
redlist_df.tail(20)
# Out:
# Core data file is: taxon.txt
# Core data file is: taxon.txt
#                  id            scientificName   kingdom    phylum class  \
# 254562     22704840       Melanodryas vittata  ANIMALIA  CHORDATA  AVES
# 254563     22704507    Dasyornis brachypterus  ANIMALIA  CHORDATA  AVES
# 254564     22709303    Humblotia flavirostris  ANIMALIA  CHORDATA  AVES
# 254565    103823897   Hypsipetes parvirostris  ANIMALIA  CHORDATA  AVES
# 254566     22703608     Atrichornis rufescens  ANIMALIA  CHORDATA  AVES
# 254567     22703612      Atrichornis clamosus  ANIMALIA  CHORDATA  AVES
# 254568     22703776         Stipiturus mallee  ANIMALIA  CHORDATA  AVES
# 254569     22703786       Amytornis dorotheae  ANIMALIA  CHORDATA  AVES
# 254570     22704493   Pardalotus quadragintus  ANIMALIA  CHORDATA  AVES
# 254571     22704751  Aphelocephala pectoralis  ANIMALIA  CHORDATA  AVES
# 254572     22704441        Manorina melanotis  ANIMALIA  CHORDATA  AVES
# 254573     22706719         Lobotos oriolinus  ANIMALIA  CHORDATA  AVES
# 254574   22706719_1       Campephaga oriolina  ANIMALIA       NaN   NaN
# 254576     22719011      Ploceus megarhynchus  ANIMALIA  CHORDATA  AVES
# 254577     22704002      Microptilotis vicina  ANIMALIA  CHORDATA  AVES
# 254578   22704002_1          Meliphaga vicina  ANIMALIA       NaN   NaN
# 254579    181767865         Aplonis metallica  ANIMALIA  CHORDATA  AVES
# 254580  181767865_1   Lamprotornis metallicus  ANIMALIA       NaN   NaN
# 254581     22714282        Cleptornis marchei  ANIMALIA  CHORDATA  AVES
# 254582     22706279   Cracticus louisiadensis  ANIMALIA  CHORDATA  AVES
#
#                 order            family          genus specificEpithet  \
# 254562  PASSERIFORMES       PETROICIDAE    Melanodryas         vittata
# 254563  PASSERIFORMES    DASYORNITHIDAE      Dasyornis    brachypterus
# 254564  PASSERIFORMES      MUSCICAPIDAE      Humblotia    flavirostris
# 254565  PASSERIFORMES      PYCNONOTIDAE     Hypsipetes    parvirostris
# 254574  BirdLife International 2022. Lobotos oriolinus...
# 254576  BirdLife International 2021. Ploceus megarhync...
# 254577  BirdLife International 2020. Microptilotis vic...
# 254578  BirdLife International 2020. Microptilotis vic...
# 254579  BirdLife International 2020. Aplonis metallica...
# 254580  BirdLife International 2020. Aplonis metallica...
# 254581  BirdLife International 2020. Cleptornis marche...
# 254582  BirdLife International 2020. Cracticus louisia...
#
#                                                references
# 254562  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254563  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254564  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254565  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254566  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254567  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254568  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254569  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254570  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254571  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254572  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254573  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254574  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254576  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254577  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254578  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254579  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254580  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254581  https://apiv3.iucnredlist.org/api/v3/taxonredi...
# 254582  https://apiv3.iucnredlist.org/api/v3/taxonredi...

# %%
# Assuming 'df' is your original Spark DataFrame and 'core_df' contains your invasive species data
obis_columns = ["marine", "class", "genus", "species", "variety", "individualCount", "eventDate", "eventTime", "year", "month", "day", "country", "locality", "decimalLongitude", "decimalLatitude"]

# Select the relevant columns and repartition
newdf = df.select(obis_columns).repartition(300)
newdf.registerTempTable('obis_data')

# Register the invasive species DataFrame as a temporary table
# Assuming 'core_df' is a Pandas DataFrame with a column 'scientificName' for invasive species
invasive_species = spark.createDataFrame(invasive_df).withColumnRenamed('scientificName', 'species')
invasive_species.registerTempTable('invasive_species')

redlist_species = spark.createDataFrame(redlist_df).withColumnRenamed('scientificName', 'species')
redlist_species.registerTempTable('redlist_species')

# Use SQL to filter 'obis_data', join with 'invasive_species', and sum 'individualCount'
aggregated_invasive_counts = spark.sql("""
    SELECT obis.species, sum(obis.individualCount) as total_individualCount
    FROM obis_data obis
    INNER JOIN invasive_species inv ON obis.species = inv.species
    WHERE obis.individualCount > 0 AND country = "Mexico"
    GROUP BY obis.species
    ORDER BY total_individualCount DESC
""")

aggregated_redlist_counts = spark.sql("""
    SELECT obis.species, sum(obis.individualCount) as total_individualCount
    FROM obis_data obis
    INNER JOIN redlist_species red ON obis.species = red.species
    WHERE obis.individualCount > 0 AND country = "Mexico"
    GROUP BY obis.species
    ORDER BY total_individualCount DESC
""")

# Show the result
aggregated_invasive_df = aggregated_invasive_counts.toPandas()
aggregated_redlist_df = aggregated_redlist_counts.toPandas()
# Out:
# 24/02/19 18:10:37 WARN TaskSetManager: Stage 99 contains a task of very large size (8050 KiB). The maximum recommended task size is 1000 KiB.

# %%
aggregated_invasive_df
# Out:
#                     species  total_individualCount
# 0      Xiphophorus hellerii                  763.0
# 1   Oreochromis mossambicus                  753.0
# 2          Gambusia affinis                  717.0
# 3       Poecilia reticulata                  308.0
# 4       Oncorhynchus mykiss                  123.0
# 5           Cyprinus carpio                   82.0
# 6       Tubastraea coccinea                   20.0
# 7           Alitta succinea                   18.0
# 8        Oreochromis aureus                   12.0
# 9         Carassius auratus                   10.0
# 10              Tinca tinca                    3.0
# 11         Pterois volitans                    2.0

# %%
aggregated_redlist_df
# Out:
#                        species  total_individualCount
# 0        Triphoturus mexicanus                11726.0
# 1     Archosargus rhomboidalis                 6359.0
# 2            Eucinostomus gula                 5625.0
# 3       Cyclothone acclinidens                 5126.0
# 4          Harengula thrissina                 4895.0
# ...                        ...                    ...
# 1945    Photonectes albipennis                    1.0
# 1946      Benthodesmus simonyi                    1.0
# 1947      Benthalbella dentata                    1.0
# 1948          Lophiodes monodi                    1.0
# 1949       Physiculus karrerae                    1.0
#
# [1950 rows x 2 columns]
