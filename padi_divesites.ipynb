# %%
# %pip install asyncio aiohttp pandas

import aiohttp
import asyncio
import pandas as pd

async def fetch_data(session, url, datakey=None):
    async with session.get(url) as response:
        print(f"Fetched {url} with status {response.status}")
        data = await response.json()
        if datakey and datakey in data:
            data = data[datakey]
        return response.status, data

async def fetch_guide_data(session, base_url):
    page = 1
    all_data = []
    while True:
        url = f"{base_url}?page={page}&page_size=1000"
        status, data = await fetch_data(session, url, datakey='results')
        # all_data.extend(data)
        # break
        if status == 404 or not data:
            break
        all_data.extend(data)
        page += 1
    return all_data




async def main():
    # Define your segments here
    # Define the size of each segment
    lat_size = 10
    lon_size = 10

    # Generate segments
    segments = []
    for lat in range(-90, 90, lat_size):
        for lon in range(-340, 340, lon_size):
            top_right = f"{lat+lat_size},{lon+lon_size}"
            bottom_left = f"{lat},{lon}"
            segments.append((top_right, bottom_left))
    # segments=[('88,340', '-88,-340')]
    async with aiohttp.ClientSession() as session:
        # Fetch guide data only once
        guide_base_url = "https://travel.padi.com/api/v2/travel/dive-guide/world/all/dive-sites/"
        guide_data = await fetch_guide_data(session, guide_base_url)

        # Fetch map data for each segment
        tasks = [fetch_data(session, f"https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right={segment[0]}&bottom_left={segment[1]}") for segment in segments]
        map_results = await asyncio.gather(*tasks)
        # Combining data into a single dictionary by ID
        all_data = {}
        print(map_results)
        print(guide_data)
        for batch in map_results:
            for item in batch[1]:
                if item['id'] in all_data:
                    all_data[item['id']].update(item)
                else:
                    all_data[item['id']] = item
        for item in guide_data:
            if item['id'] in all_data:
                all_data[item['id']].update(item)
            else:
                all_data[item['id']] = item

        # Convert the dictionary to a pandas DataFrame
        df = pd.DataFrame.from_dict(all_data, orient='index')
        return df

# Running the async main function
df = await main()
df.to_csv('dive_sites.csv.gz', index=False, compression='gzip')
# The resulting DataFrame 'df' contains your combined data
# Out:
# Requirement already satisfied: asyncio in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (3.4.3)
# Requirement already satisfied: aiohttp in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (3.9.3)
# Requirement already satisfied: pandas in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (from aiohttp) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (from aiohttp) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (from aiohttp) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (from aiohttp) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (from aiohttp) (1.9.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: idna>=2.0 in /Users/helloworld/Projects/marine_venv/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp) (3.6)
# Note: you may need to restart the kernel to use updated packages.
# Fetched https://travel.padi.com/api/v2/travel/dive-guide/world/all/dive-sites/?page=1&page_size=1000 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dive-guide/world/all/dive-sites/?page=2&page_size=1000 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dive-guide/world/all/dive-sites/?page=3&page_size=1000 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dive-guide/world/all/dive-sites/?page=4&page_size=1000 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dive-guide/world/all/dive-sites/?page=5&page_size=1000 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dive-guide/world/all/dive-sites/?page=6&page_size=1000 with status 404
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-330&bottom_left=-90,-340 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-320&bottom_left=-90,-330 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-250&bottom_left=-90,-260 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-300&bottom_left=-90,-310 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-270&bottom_left=-90,-280 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-260&bottom_left=-90,-270 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-220&bottom_left=-90,-230 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-150&bottom_left=-90,-160 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-100&bottom_left=-90,-110 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-230&bottom_left=-90,-240 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,100&bottom_left=-90,90 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,10&bottom_left=-90,0 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-130&bottom_left=-90,-140 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-180&bottom_left=-90,-190 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-210&bottom_left=-90,-220 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,50&bottom_left=-90,40 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-30&bottom_left=-90,-40 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,0&bottom_left=-90,-10 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-40&bottom_left=-90,-50 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-280&bottom_left=-90,-290 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80,-10&bottom_left=-90,-20 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=-80
 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,-60&bottom_left=80,-70 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,-50&bottom_left=80,-60 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,-40&bottom_left=80,-50 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,-30&bottom_left=80,-40 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,-20&bottom_left=80,-30 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,-10&bottom_left=80,-20 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,0&bottom_left=80,-10 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,10&bottom_left=80,0 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,20&bottom_left=80,10 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,30&bottom_left=80,20 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,40&bottom_left=80,30 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,50&bottom_left=80,40 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,60&bottom_left=80,50 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,70&bottom_left=80,60 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,80&bottom_left=80,70 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,90&bottom_left=80,80 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,100&bottom_left=80,90 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,110&bottom_left=80,100 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,120&bottom_left=80,110 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,130&bottom_left=80,120 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,140&bottom_left=80,130 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,150&bottom_left=80,140 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,160&bottom_left=80,150 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,170&bottom_left=80,160 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,180&bottom_left=80,170 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,200&bottom_left=80,190 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,190&bottom_left=80,180 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,210&bottom_left=80,200 with status 200
# Fetched https://travel.padi.com/api/v2/travel/dsl/dive-sites/map/?top_right=90,220&bottom_left=80,210 with status 200
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
divesites = pd.read_csv('dive_sites.csv.gz', compression='gzip')
divesites.columns
# Out:
# Index(['id', 'latitude', 'longitude', 'images', 'marineLife', 'maximumDepth',
#        'title', 'travelUrl', 'types'],
#       dtype='object')

# %%
not_null_df = divesites[divesites['title'] == 'Hole in the Wall']
not_null_df
# Out:
#         id   latitude   longitude  \
# 1718  2618  12.461909  -69.966742
# 2171  4242  13.522000  120.900000
# 2783   699  25.340846   56.378188
#
#                                                  images marineLife  \
# 1718                                                 []         []
# 2171  [{'800x800': 'https://d2p1cf6997m1ir.cloudfron...         []
# 2783  [{'800x800': 'https://d2p1cf6997m1ir.cloudfron...         []
#
#                                            maximumDepth             title  \
# 1718                                                NaN  Hole in the Wall
# 2171  {'FEET': {'value': 49.2126, 'title': 'Feet'}, ...  Hole in the Wall
# 2783                                                NaN  Hole in the Wall
#
#                                               travelUrl  \
# 1718               /dive-site/aruba/hole-in-the-wall-2/
# 2171         /dive-site/philippines/hole-in-the-wall-3/
# 2783  /dive-site/united-arab-emirates/hole-in-the-wall/
#
#                            types
# 1718           ['Beach', 'Reef']
# 2171  ['Reef', 'Wall', 'Cavern']
# 2783                    ['Reef']

# %%
# Out:
#      id   latitude  longitude  \
# 4  1193 -42.734531 -65.030780
# 6  1194 -42.765446 -65.022883
# 7  1195 -42.770361 -65.021617
# 8  1189 -42.772156 -65.009880
# 9  1187 -42.774109 -65.009708
#
#                                               images marineLife maximumDepth  \
# 4  [{'800x800': 'https://d2p1cf6997m1ir.cloudfron...         []          NaN
# 6  [{'800x800': 'https://d2p1cf6997m1ir.cloudfron...         []          NaN
# 7  [{'800x800': 'https://d2p1cf6997m1ir.cloudfron...         []          NaN
# 8  [{'800x800': 'https://d2p1cf6997m1ir.cloudfron...         []          NaN
# 9  [{'800x800': 'https://d2p1cf6997m1ir.cloudfron...         []          NaN
#
#                   title                                   travelUrl  \
# 4    Parque las Piedras    /dive-site/argentina/parque-las-piedras/
# 6        Naufragio Emma        /dive-site/argentina/naufragio-emma/
# 7          Parque Nuevo          /dive-site/argentina/parque-nuevo/
# 8  Hundimiento Albatros  /dive-site/argentina/hundimiento-albatros/
# 9   Hundimiento Urabain   /dive-site/argentina/hundimiento-urabain/
#
#                types
# 4           ['Reef']
# 6           ['Reef']
# 7  ['Beach', 'Reef']
# 8           ['Reef']
# 9           ['Reef']
